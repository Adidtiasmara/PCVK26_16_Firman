# %% [markdown]
# <a href="https://colab.research.google.com/github/Adidtiasmara/PCVK26_16_Firman/blob/main/P1_Tugas_D2_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum D1
# 1. Pembuatan Repository
# ![repoPCVK.png](data:image/png;base64,...)
#
# 2. Connect githu dan colab
# ![image.png](data:image/png;base64,...)
#   ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %%
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://images.unsplash.com/photo-1519608487953-e999c86e7455?w=800"
]

for url in urls:
    image = io.imread(url)
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    final_frame = cv.hconcat((image, image_2))
    cv2_imshow(final_frame)
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x266>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  266  x  400
# <PIL.Image.Image image mode=RGB size=400x266>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x266>

# %% [markdown]
# PERTANYAAN PRAKTIKUM D2
# 1. Jelaskan mengapa modul praktikum ini ekseskusi Python dilakukan menggunakan Google Colab?
#
#     Jawab: Menggunakan Google Colab karena pada google colab sudah tersedia library untuk python sehingga bisa langsung digunakan di browser tanpa harus melakukan instalasi library secara manual di laptop
#
# 2.  Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#     Jawab:
#      - Numpy digunakan untuk mengolah arrat dalam pengolahan citra
#      - Pandas Digunakan untuk mengolah dan menganalisis data dalam bentuk tabel
#      - OpenCV digunakanuntuk membaca dan memproses gambar
#      - skimage digunaakan untuk berbagai proses dalam pengolahan citra, seperti
#      - PIL digunakan untuk membuka, memproses, dan menmanipulasi file gambar
#      - Matplotlib digunakan untuk menampilkan gambar dalam bentuk plot atau visual
#
#     Library tersebut tidak semua harus digunakan. Penggunaann tergantung pada setiap kebutuhan
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#   ![image.png](data:image/png;base64,...)
#   Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
#
#     Jawab: Kode tersebut digunakan untuk mengakses dan mengubah pixel pada gambar, kemudian memberikan garis atau perubahan warna pada bagian tertentu dari gambar.
#
# 4. Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
#     Jawab: Kode [255,255,255] merupakan nilai untuk warna putih pada citra RGB.
#
# 5. Jelaskan keterkaitan antara pixel dan resolusi gambar yang tinggi ataupun rendah!
#
#     Jawab: Pixel merupakan elemen terkecil yang membentuk sebuah gambar. Sedangkan resolusi menunjukkan jumlah pixel yang terdapat pada gambar dalam arah horizontal dan vertikal.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x266>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    y = int(x * lebar / tinggi)
    image_3[x, y] = [255, 255, 255]

for x in range(tinggi):
    y = (lebar - 1) - int(x * lebar / tinggi)
    image_3[x, y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x266>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar, _ = image_3.shape

# Batasi range y agar garis hanya digambar di area tengah saja
for y in range(int(lebar / 4), int(2* lebar / 4)):
    image_3[int(tinggi / 2), y] = [255, 255, 255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x266>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
for x in range(int(lebar/4), int(2*lebar/4)):
    for y in range(int(tinggi/3), int(2*tinggi/3)):
        image_3[x, y] = [255, 255, 255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x266>
